# %% [markdown]
# This is an example of the following function:
#
# $$y = \sin{x}$$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.0,40.0,0.1)
y = np.sin(x)

plt.plot(x,y, color='r')
plt.plot(x,y, color = 'g')
